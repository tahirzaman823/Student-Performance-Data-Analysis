# %%
import pandas as pd

d1 = pd.read_csv("cleaned_Student_Math_data.csv")

d2 = pd.read_csv("cleaned_student_por.csv")

# %%
d3 = pd.merge(
    d1,
    d2,
    on=[
        "school",
        "sex",
        "age",
        "address",
        "famsize",
        "Pstatus",
        "Medu",
        "Fedu",
        "Mjob",
        "Fjob",
        "reason",
        "nursery",
        "internet"
    ]
)

print(len(d3))
# Out:
# 382
